# %%
import pandas as pd
import numpy as np
import scipy.optimize as opt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("breast cancer kaggle.csv")

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0    842302         M        17.99         10.38          122.80     1001.0  \
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
feature_df = data[['concave points_mean', 'fractal_dimension_mean', 'smoothness_mean', 'texture_mean']]
X = np.asanyarray(feature_df)

# %%
data.head(30)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0     842302         M       17.990         10.38          122.80     1001.0  \
# 1     842517         M       20.570         17.77          132.90     1326.0
# 2   84300903         M       19.690         21.25          130.00     1203.0
# 3   84348301         M       11.420         20.38           77.58      386.1
# 4   84358402         M       20.290         14.34          135.10     1297.0
# 5     843786         M       12.450         15.70           82.57      477.1
# 6     844359         M       18.250         19.98          119.60     1040.0
# 7   84458202         M       13.710         20.83           90.20      577.9
# 8     844981         M       13.000         21.82           87.50      519.8
# 9   84501001         M       12.460         24.04           83.97      475.9
# 10    845636         M       16.020         23.24          102.70      797.8
# ...

# %%
data['diagnosis'] = data['diagnosis'].astype('object')
y = np.asanyarray(data['diagnosis'])

# %%
x_tr, x_te, y_tr, y_te = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
print("Train Set: ", x_tr.shape, y_tr.shape)
print("Test Set: ", x_te.shape, y_te.shape)
# Out:
# Train Set:  (455, 4) (455,)
# Test Set:  (114, 4) (114,)

# %%
from sklearn import svm

# %%
sm = svm.SVC(kernel='rbf')
sm.fit(x_tr, y_tr)
# Out:
# SVC()

# %%
yhat = sm.predict(x_te)
yhat[0:5]
# Out:
# array(['B', 'M', 'B', 'M', 'B'], dtype=object)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools

# %%
from sklearn.metrics import f1_score, jaccard_score

# %%
print('F1 Score: ', f1_score(y_te, yhat, average='weighted'))
print('Jaccard Score: ', jaccard_score(y_te, yhat, pos_label='B'))
# Out:
# F1 Score:  0.683160188051829
# Jaccard Score:  0.6105263157894737
